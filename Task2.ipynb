# %% [markdown]
# <a href="https://colab.research.google.com/github/Gayathripanchavati/FoodDelivery-app/blob/main/Task2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Task
# Create dashboards using the data from "/content/tested.csv".

# %% [markdown]
# ## Load the data
#
# ### Subtask:
# Load the data from "/content/tested.csv" into a pandas DataFrame.

# %% [markdown]
# **Reasoning**:
# Import the pandas library and load the data from the CSV file into a DataFrame.

# %%
import pandas as pd

df = pd.read_csv('/content/tested.csv')

# %% [markdown]
# **Reasoning**:
# Display the first few rows of the DataFrame to verify the data has been loaded correctly.

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %% [markdown]
# ## Explore the data
#
# ### Subtask:
# Explore the data by displaying the first few rows, checking the data types, and looking for missing values.

# %% [markdown]
# **Reasoning**:
# Display the first 5 rows of the DataFrame, check the data types, and calculate the number of missing values for each column.

# %%
display(df.head())
display(df.info())
display(df.isnull().sum())
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# ...

# %% [markdown]
# ## Clean the data
#
# ### Subtask:
# Handle missing values and convert data types if necessary.

# %% [markdown]
# **Reasoning**:
# Fill missing 'Age' and 'Fare' values with their respective medians and drop the 'Cabin' column.

# %%
df['Age'].fillna(df['Age'].median(), inplace=True)
df['Fare'].fillna(df['Fare'].median(), inplace=True)
df.drop('Cabin', axis=1, inplace=True)
display(df.isnull().sum())
# Out:
# /tmp/ipython-input-1522611015.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].median(), inplace=True)
# /tmp/ipython-input-1522611015.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %% [markdown]
# **Reasoning**:
# Check the data types and convert any object types that represent numerical or categorical data to appropriate formats.

# %%
display(df.info())
df['Sex'] = df['Sex'].astype('category')
df['Embarked'] = df['Embarked'].astype('category')
display(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          418 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         418 non-null    float64
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 36.1+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
# ...

# %% [markdown]
# ## Analyze the data
#
# ### Subtask:
# Perform some basic analysis to understand the data distribution and relationships between columns.

# %% [markdown]
# **Reasoning**:
# Perform the requested basic analysis steps: calculate descriptive statistics, value counts for categorical columns, and the correlation matrix.

# %%
display(df.describe())
display(df['Sex'].value_counts())
display(df['Embarked'].value_counts())
display(df.corr(numeric_only=True))
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  418.000000  418.000000
# mean   1100.500000    0.363636    2.265550   29.599282    0.447368
# std     120.810458    0.481622    0.841838   12.703770    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   23.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   35.750000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  418.000000
# mean     0.392344   35.576535
# std      0.981429   55.850103
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.471875
# max      9.000000  512.329200
# Sex
# male      266
# female    152
# Name: count, dtype: int64
# Embarked
# ...

# %% [markdown]
# ## Create visualizations
#
# ### Subtask:
# Generate relevant plots and charts to visualize the data.

# %% [markdown]
# **Reasoning**:
# Generate plots to visualize the data distribution and relationships between columns as requested in the instructions.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set up the figure size for better readability
plt.figure(figsize=(18, 15))

# 1. Histogram of 'Age'
plt.subplot(3, 3, 1)
sns.histplot(df['Age'].dropna(), kde=True)
plt.title('Distribution of Age')

# 2. Bar plot of 'Survived'
plt.subplot(3, 3, 2)
sns.countplot(x='Survived', data=df)
plt.title('Distribution of Survived')
plt.xticks([0, 1], ['Not Survived', 'Survived'])

# 3. Bar plot of 'Pclass'
plt.subplot(3, 3, 3)
sns.countplot(x='Pclass', data=df)
plt.title('Distribution of Passenger Class')

# 4. Bar plot of 'Sex'
plt.subplot(3, 3, 4)
sns.countplot(x='Sex', data=df)
plt.title('Distribution of Sex')

# 5. Bar plot of 'Embarked'
plt.subplot(3, 3, 5)
sns.countplot(x='Embarked', data=df)
plt.title('Distribution of Embarkation Point')

# 6. Scatter plot of 'Age' vs 'Fare'
plt.subplot(3, 3, 6)
sns.scatterplot(x='Age', y='Fare', data=df)
plt.title('Age vs Fare')

# 7. Box plot of 'Fare' by 'Pclass'
plt.subplot(3, 3, 7)
sns.boxplot(x='Pclass', y='Fare', data=df)
plt.title('Fare Distribution by Passenger Class')

# 8. Box plot of 'Age' by 'Survived'
plt.subplot(3, 3, 8)
sns.boxplot(x='Survived', y='Age', data=df)
plt.title('Age Distribution by Survived Status')
plt.xticks([0, 1], ['Not Survived', 'Survived'])

# 9. Box plot of 'Fare' by 'Survived'
plt.subplot(3, 3, 9)
sns.boxplot(x='Survived', y='Fare', data=df)
plt.title('Fare Distribution by Survived Status')
plt.xticks([0, 1], ['Not Survived', 'Survived'])

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Build dashboards
#
# ### Subtask:
# Use a library like `panel` or `voila` to create interactive dashboards from the visualizations.

# %% [markdown]
# **Reasoning**:
# Import the panel library and store the plots generated in the previous step in a list to prepare for creating the dashboard.

# %%
import panel as pn

# Assuming the plots from the previous step are stored in matplotlib figure objects
# and that you want to create a dashboard with them.
# In the previous step, we used subplots within a single figure.
# To use panel effectively, it's better to create individual figures for each plot.

# Re-generating the plots as individual figures for panel
plot_age_hist = sns.histplot(df['Age'].dropna(), kde=True).get_figure()
plt.close(plot_age_hist) # Close the figure to prevent it from displaying twice

plot_survived_bar = sns.countplot(x='Survived', data=df).get_figure()
plt.close(plot_survived_bar)

plot_pclass_bar = sns.countplot(x='Pclass', data=df).get_figure()
plt.close(plot_pclass_bar)

plot_sex_bar = sns.countplot(x='Sex', data=df).get_figure()
plt.close(plot_sex_bar)

plot_embarked_bar = sns.countplot(x='Embarked', data=df).get_figure()
plt.close(plot_embarked_bar)

plot_age_fare_scatter = sns.scatterplot(x='Age', y='Fare', data=df).get_figure()
plt.close(plot_age_fare_scatter)

plot_fare_pclass_box = sns.boxplot(x='Pclass', y='Fare', data=df).get_figure()
plt.close(plot_fare_pclass_box)

plot_age_survived_box = sns.boxplot(x='Survived', y='Age', data=df).get_figure()
plt.close(plot_age_survived_box)

plot_fare_survived_box = sns.boxplot(x='Survived', y='Fare', data=df).get_figure()
plt.close(plot_fare_survived_box)


# Create a list of the generated plots
plots = [
    plot_age_hist,
    plot_survived_bar,
    plot_pclass_bar,
    plot_sex_bar,
    plot_embarked_bar,
    plot_age_fare_scatter,
    plot_fare_pclass_box,
    plot_age_survived_box,
    plot_fare_survived_box,
]

# Arrange the plots in a visually appealing layout using panel
# Example: Two rows of plots
dashboard_layout = pn.Column(
    pn.Row(plots[0], plots[1], plots[2]),
    pn.Row(plots[3], plots[4], plots[5]),
    pn.Row(plots[6], plots[7], plots[8])
)

# To serve the panel layout, you would typically run this in a script or a dedicated cell
# dashboard_layout.servable()
# Or to serve directly in a notebook, you can use:
# dashboard_layout.show()
# However, for the purpose of this task within the provided environment,
# we will just create the layout and report success.
# Running .serve() or .show() would block the execution flow.

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The dataset contains 418 entries and 12 columns with a mix of numerical and object data types.
# *   Missing values were present, most significantly in the 'Cabin' column (327), followed by 'Age' (86) and 'Fare' (1).
# *   Missing values in 'Age' and 'Fare' were imputed with their respective median values, and the 'Cabin' column was dropped.
# *   The data types for 'Sex' and 'Embarked' were converted from 'object' to 'category'.
# *   Descriptive statistics show an average age of around 29.6 and an average fare of about \$35.6.
# *   The majority of passengers are male (266), and the most common embarkation point is 'S' (270).
# *   Notable correlations include a moderate negative correlation between Pclass and Fare (-0.577) and a moderate positive correlation between Age and Fare (0.342).
# *   Various visualizations were successfully generated, including histograms, bar plots, scatter plots, and box plots, to illustrate data distributions and relationships.
# *   A dashboard layout containing the generated plots was successfully created using the `panel` library, although the serving of the dashboard was not executed.
#
# ### Insights or Next Steps
#
# *   The analysis provides a good understanding of the passenger demographics, class distribution, and survival outcomes in the tested dataset.
# *   The created `panel` layout can be served to create an interactive dashboard for further exploration and presentation of the data.
